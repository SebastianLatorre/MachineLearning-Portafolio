# %% [markdown]
# # **Grupo:**
# Rodrigo Molina Mantelli
# Sebastian Latorre Diaz

# %% [markdown]
# #1A
# El siguiente codigo, tanto de la parte A) como de la B), se obtuvieron de la siguiente fuente "https://www.kaggle.com/code/krishnayogi/classification-using-decision-tree"

# %% [markdown]
# ##DataSet

# %%
# !gdown 17amWXqnysoX_9pwue1MWEMkUtirqK3JY
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17amWXqnysoX_9pwue1MWEMkUtirqK3JY
# To: /content/Iris.csv
# 100% 5.26k/5.26k [00:00<00:00, 12.7MB/s]

# %%
import pandas as pd                            # File Handling
import numpy as np

# %%
Dataset = pd.read_csv('Iris.csv')
Dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn.model_selection import train_test_split                # Splitting Dataset into Train/Test sets

# %%
from sklearn.tree import DecisionTreeClassifier                     # For implementing Decision Tree classifier

# %%
from sklearn.metrics import accuracy_score                          # For calculating accuracy
from sklearn.metrics import classification_report                   # For evaluating the model
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

# %% [markdown]
# ##Modelo de Ml decision tree

# %%
from sklearn import tree                                            # Visualizing Decision Tree

# %%
Dataset = pd.read_csv("Iris.csv")

# %%
Dataset = Dataset.dropna()

# %%
Dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Dataset.shape
# Out:
# (150, 6)

# %%
Dataset["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
Dataset = Dataset.replace(to_replace ="Iris-setosa",          value ="0")
Dataset = Dataset.replace(to_replace ="Iris-versicolor",      value ="1")
Dataset = Dataset.replace(to_replace ="Iris-virginica",       value ="2")

# %%
X = np.array(Dataset[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']])                   # Input
Y = np.array(Dataset["Species"])                                                                            # Targets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 100)

# %% [markdown]
# ##Arbol 1

# %% [markdown]
# *Test Size: 0.2*
#
# *Criterio: GINI*
#
# *Profundidad: 5*

# %%
clf_gini_PROFUNDIDAD_5_02 = DecisionTreeClassifier(criterion = "gini",                # Criterion
                                  max_depth = 5,                     # Max Height of Tree
                                  min_samples_leaf = 3,              # Maximum Leaf samples
                                  random_state = 100)

# %%
clf_gini_PROFUNDIDAD_5_02.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=3, random_state=100)

# %%
y_pred_ginI_5 = clf_gini_PROFUNDIDAD_5_02.predict(X_test)

# %%
score = cross_val_score(clf_gini_PROFUNDIDAD_5_02, X, Y, cv=7)
print ("Score : ",score)
print("Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print ("Report : ",  classification_report(Y_test, y_pred_ginI_5))
# Out:
# Score :  [0.95454545 1.         0.90909091 0.80952381 0.85714286 1.
#  1.        ]
# Accuracy: 0.93 (+/- 0.14)
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.83      0.91         6
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ##Arbol 2

# %% [markdown]
# Test Size: 0.2
#
# Criterio: GINI
#
# Profundidad: 2

# %%
clf_gini_PROFUNDIDAD_2_02 = DecisionTreeClassifier(criterion = "gini",                # Criterion
                                  max_depth = 2,                     # Max Height of Tree
                                  min_samples_leaf = 3,              # Maximum Leaf samples
                                  random_state = 100)

# %%
clf_gini_PROFUNDIDAD_2_02.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=3, random_state=100)

# %%
y_pred_gini_2 = clf_gini_PROFUNDIDAD_2_02.predict(X_test)

# %%
score = cross_val_score(clf_gini_PROFUNDIDAD_2_02, X, Y, cv=7)
print ("Score : ",score)
print("Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print ("Report : ",  classification_report(Y_test, y_pred_gini_2))
# Out:
# Score :  [0.90909091 1.         0.90909091 0.85714286 0.85714286 1.
#  1.        ]
# Accuracy: 0.93 (+/- 0.12)
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.83      0.91         6
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ##Arbol 3

# %% [markdown]
# Test Size: 0.2
#
# Criterio: ENTROPIA
#
# Profundidad: 5

# %%
clf_entropy_PROFUNDIDAD_5_02 = DecisionTreeClassifier(criterion = "entropy",          # Criterion
                                     max_depth = 5,                  # Max Height of Tree
                                     min_samples_leaf = 3,           # Max Leaf samples
                                     random_state = 100)

# %%
clf_entropy_PROFUNDIDAD_5_02.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=3,
#                        random_state=100)

# %%
y_pred_entropy_5 = clf_entropy_PROFUNDIDAD_5_02.predict(X_test)

# %%
score = cross_val_score(clf_entropy_PROFUNDIDAD_5_02, X, Y, cv=7)
print ("Score : ",score)
print("Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print ("Report : ",  classification_report(Y_test, y_pred_entropy_5))
# Out:
# Score :  [0.95454545 1.         0.90909091 0.80952381 0.85714286 1.
#  1.        ]
# Accuracy: 0.93 (+/- 0.14)
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.83      0.91         6
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
print ("Accuracy : ", accuracy_score(Y_test,y_pred_entropy_5)*100)            # Evaulating predictions with test labels
print ("Report : ",  classification_report(Y_test, y_pred_entropy_5))
# Out:
# Accuracy :  96.66666666666667
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.83      0.91         6
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ##Arbol 4

# %% [markdown]
# Test Size: 0.2
#
# Criterio: ENTROPIA
#
# Profundidad: 2

# %%
clf_entropy_PROFUNDIDAD_2_02 = DecisionTreeClassifier(criterion = "entropy",          # Criterion
                                     max_depth = 2,                  # Max Height of Tree
                                     min_samples_leaf = 3,           # Max Leaf samples
                                     random_state = 100)

# %%
clf_entropy_PROFUNDIDAD_2_02.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_leaf=3,
#                        random_state=100)

# %%
y_pred_entropy_2= clf_entropy_PROFUNDIDAD_2_02.predict(X_test)

# %%
score = cross_val_score(clf_entropy_PROFUNDIDAD_2_02, X, Y, cv=7)
print ("Score : ",score)
print("Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print ("Report : ",  classification_report(Y_test, y_pred_entropy_2))
# Out:
# Score :  [0.90909091 1.         0.90909091 0.85714286 0.85714286 1.
#  1.        ]
# Accuracy: 0.93 (+/- 0.12)
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.83      0.91         6
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ##Arbol 5

# %% [markdown]
# Test Size: 0.6
#
# Criterio: Gini
#
# Profundidad: 5

# %%
X_train_2, X_test_2, Y_train_2, Y_test_2 = train_test_split(X, Y, test_size=0.6, random_state = 100)

# %%
clf_gini_PROFUNDIDAD_5_06 = DecisionTreeClassifier(criterion = "gini",                # Criterion
                                  max_depth = 5,                     # Max Height of Tree
                                  min_samples_leaf = 3,              # Maximum Leaf samples
                                  random_state = 100)

# %%
clf_gini_PROFUNDIDAD_5_06.fit(X_train_2, Y_train_2)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=3, random_state=100)

# %%
y_pred_ginI_5_06 = clf_gini_PROFUNDIDAD_5_06.predict(X_test_2)

# %%
score = cross_val_score(clf_gini_PROFUNDIDAD_5_06, X, Y, cv=7)
print ("Score : ",score)
print("Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print ("Report : ",  classification_report(Y_test_2, y_pred_ginI_5_06))
# Out:
# Score :  [0.95454545 1.         0.90909091 0.80952381 0.85714286 1.
#  1.        ]
# Accuracy: 0.93 (+/- 0.14)
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       0.88      0.85      0.87        27
#            2       0.88      0.91      0.89        32
#
#     accuracy                           0.92        90
#    macro avg       0.92      0.92      0.92        90
# weighted avg       0.92      0.92      0.92        90

# %% [markdown]
# ##Arbol 6

# %% [markdown]
# Test Size: 0.6
#
# Criterio: Gini
#
# Profundidad: 2

# %%
clf_gini_PROFUNDIDAD_2_06 = DecisionTreeClassifier(criterion = "gini",                # Criterion
                                  max_depth = 2,                     # Max Height of Tree
                                  min_samples_leaf = 3,              # Maximum Leaf samples
                                  random_state = 100)

# %%
clf_gini_PROFUNDIDAD_2_06.fit(X_train_2, Y_train_2)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=3, random_state=100)

# %%
y_pred_gini_2_06 = clf_gini_PROFUNDIDAD_2_06.predict(X_test_2)

# %%
score = cross_val_score(clf_gini_PROFUNDIDAD_2_06, X, Y, cv=7)
print ("Score : ",score)
print("Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print ("Report : ",  classification_report(Y_test_2, y_pred_gini_2_06))
# Out:
# Score :  [0.90909091 1.         0.90909091 0.85714286 0.85714286 1.
#  1.        ]
# Accuracy: 0.93 (+/- 0.12)
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       0.88      0.85      0.87        27
#            2       0.88      0.91      0.89        32
#
#     accuracy                           0.92        90
#    macro avg       0.92      0.92      0.92        90
# weighted avg       0.92      0.92      0.92        90

# %% [markdown]
# ##Arbol 7

# %% [markdown]
# Test Size: 0.6
#
# Criterio: ENTROPIA
#
# Profundidad: 5

# %%
clf_entropy_PROFUNDIDAD_5_06 = DecisionTreeClassifier(criterion = "entropy",                # Criterion
                                  max_depth = 5,                     # Max Height of Tree
                                  min_samples_leaf = 3,              # Maximum Leaf samples
                                  random_state = 100)

# %%
clf_entropy_PROFUNDIDAD_5_06.fit(X_train_2, Y_train_2)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=3,
#                        random_state=100)

# %%
y_pred_entropy_5_06= clf_entropy_PROFUNDIDAD_5_06.predict(X_test_2)

# %%
score = cross_val_score(clf_entropy_PROFUNDIDAD_5_06, X, Y, cv=7)
print ("Score : ",score)
print("Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print ("Report : ",  classification_report(Y_test_2, y_pred_entropy_5_06))
# Out:
# Score :  [0.95454545 1.         0.90909091 0.80952381 0.85714286 1.
#  1.        ]
# Accuracy: 0.93 (+/- 0.14)
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       0.88      0.85      0.87        27
#            2       0.88      0.91      0.89        32
#
#     accuracy                           0.92        90
#    macro avg       0.92      0.92      0.92        90
# weighted avg       0.92      0.92      0.92        90

# %% [markdown]
# ##Arbol 8

# %% [markdown]
# Test Size: 0.6
#
# Criterio: ENTROPIA
#
# Profundidad: 2

# %%
clf_entropy_PROFUNDIDAD_2_06 = DecisionTreeClassifier(criterion = "entropy",          # Criterion
                                     max_depth = 2,                  # Max Height of Tree
                                     min_samples_leaf = 3,           # Max Leaf samples
                                     random_state = 100)

# %%
clf_entropy_PROFUNDIDAD_2_06.fit(X_train_2, Y_train_2)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_leaf=3,
#                        random_state=100)

# %%
y_pred_entropy_2_06= clf_entropy_PROFUNDIDAD_2_06.predict(X_test_2)

# %%
score = cross_val_score(clf_entropy_PROFUNDIDAD_2_06, X, Y, cv=7)
print ("Score : ",score)
print("Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print ("Report : ",  classification_report(Y_test_2, y_pred_entropy_2_06))
# Out:
# Score :  [0.90909091 1.         0.90909091 0.85714286 0.85714286 1.
#  1.        ]
# Accuracy: 0.93 (+/- 0.12)
# Report :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       0.88      0.85      0.87        27
#            2       0.88      0.91      0.89        32
#
#     accuracy                           0.92        90
#    macro avg       0.92      0.92      0.92        90
# weighted avg       0.92      0.92      0.92        90

# %% [markdown]
# ##Arbol 9  CrossValidation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score, confusion_matrix
import seaborn as sns

# Cargar datos de ejemplo
data = load_iris()
X = data.data  # Usar todas las características disponibles
Y = data.target

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# Definir los hiperparámetros a ajustar utilizando Grid Search Cross-Validation
hyperparameters = [{'max_depth': [1, 2, 3, 4, 5], 'criterion': ['gini', 'entropy']}]

# Crear el modelo DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=0)

# Usar validación cruzada con GridSearchCV donde cv=5
grid_search = GridSearchCV(model, hyperparameters, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, Y_train)

# Obtener los mejores hiperparámetros encontrados
best_params = grid_search.best_params_

# Entrenar el modelo con los mejores hiperparámetros
best_model = DecisionTreeClassifier(**best_params, random_state=0)
best_model.fit(X_train, Y_train)

# Obtener el valor de Gini o Entropy del nodo raíz
root_impurity = best_model.tree_.impurity[0]
criterion_used = best_model.criterion

print(f'Criterio utilizado: {criterion_used}')
print(f'Valor de Gini o Entropy en el nodo raíz: {root_impurity}')

# Realizar predicciones en el conjunto de prueba
predictions = best_model.predict(X_test)

# Calcular métricas de evaluación
mse = mean_squared_error(Y_test, predictions)
r2 = r2_score(Y_test, predictions)
accuracy = accuracy_score(Y_test, predictions)

print(f'MSE: {mse}')
print(f'R²: {r2}')
print(f'Accuracy: {accuracy}')
print(f'Best Parameters: {best_params}')

# Calcular y mostrar la matriz de confusión
plt.figure(figsize=(6, 4))
conf_matrix = confusion_matrix(Y_test, predictions)
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Criterio utilizado: gini
# Valor de Gini o Entropy en el nodo raíz: 0.6643083900226757
# MSE: 0.022222222222222223
# R²: 0.9621848739495799
# Accuracy: 0.9777777777777777
# Best Parameters: {'criterion': 'gini', 'max_depth': 3}

# %% [markdown]
# #1B

# %% [markdown]
# **Arboles de decision con las respectivas variables mas representantes de acuerdo al Teste Size, Modelo entrenaday Profundidad.**
#
# **Discusión  sobre la variaes mas importantes y los resultados obtenidos al final del codigo**

# %% [markdown]
# ##Arbol 1

# %% [markdown]
# *Test Size: 0.2*
#
# *Criterio: Gini*
#
# *Profundidad: 5*
#
#
# **Variables mas importente: **
# 1.   Petal Length <= 2.45
# 2.   Petal Width <= 1.65
# 3.   Petal Length <= 4.95
# 3.   Petal Length <= 4.85

# %%
tree.plot_tree(clf_gini_PROFUNDIDAD_5_02)
# Out:
# [Text(0.375, 0.875, 'x[2] <= 2.45\ngini = 0.665\nsamples = 120\nvalue = [39, 44, 37]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.5, 0.625, 'x[3] <= 1.65\ngini = 0.496\nsamples = 81\nvalue = [0, 44, 37]'),
#  Text(0.25, 0.375, 'x[2] <= 4.95\ngini = 0.156\nsamples = 47\nvalue = [0, 43, 4]'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 42\nvalue = [0, 42, 0]'),
#  Text(0.375, 0.125, 'gini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.75, 0.375, 'x[2] <= 4.85\ngini = 0.057\nsamples = 34\nvalue = [0, 1, 33]'),
#  Text(0.625, 0.125, 'gini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 30]')]

# %% [markdown]
# ##Arbol 2

# %% [markdown]
# *Test Size: 0.2*
#
# *Criterio: Gini*
#
# *Profundidad: 2*
#
# **Variables mas importente: **
# 1.   Petal Length <= 2.45
# 2.   Petal Width <= 1.65

# %%
tree.plot_tree(clf_gini_PROFUNDIDAD_2_02)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 2.45\ngini = 0.665\nsamples = 120\nvalue = [39, 44, 37]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.6, 0.5, 'x[3] <= 1.65\ngini = 0.496\nsamples = 81\nvalue = [0, 44, 37]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.156\nsamples = 47\nvalue = [0, 43, 4]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.057\nsamples = 34\nvalue = [0, 1, 33]')]

# %% [markdown]
# ##Arbol 3

# %% [markdown]
# *Test Size: 0.2*
#
# *Criterio: Entropia*
#
# *Profundidad: 5*
#
# *Variables mas importente: *
# 1.   Petal Length <= 2.45
# 2.   Petal Width <= 1.65
# 3.   Petal Length <= 4.95
# 4.   Petal Length <= 4.85

# %%
tree.plot_tree(clf_entropy_PROFUNDIDAD_5_02)
# Out:
# [Text(0.375, 0.875, 'x[2] <= 2.45\nentropy = 1.581\nsamples = 120\nvalue = [39, 44, 37]'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.5, 0.625, 'x[3] <= 1.65\nentropy = 0.995\nsamples = 81\nvalue = [0, 44, 37]'),
#  Text(0.25, 0.375, 'x[2] <= 4.95\nentropy = 0.42\nsamples = 47\nvalue = [0, 43, 4]'),
#  Text(0.125, 0.125, 'entropy = 0.0\nsamples = 42\nvalue = [0, 42, 0]'),
#  Text(0.375, 0.125, 'entropy = 0.722\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.75, 0.375, 'x[2] <= 4.85\nentropy = 0.191\nsamples = 34\nvalue = [0, 1, 33]'),
#  Text(0.625, 0.125, 'entropy = 0.811\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 30\nvalue = [0, 0, 30]')]

# %% [markdown]
# ##Arbol 4

# %% [markdown]
# *Test Size: 0.2*
#
# *Criterio: Entropia*
#
# *Profundidad: 2*
#
# *Variables mas importente: *
# 1.   Petal Length <= 2.45
# 2.   Petal Width <= 1.65

# %%
tree.plot_tree(clf_entropy_PROFUNDIDAD_2_02)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 2.45\nentropy = 1.581\nsamples = 120\nvalue = [39, 44, 37]'),
#  Text(0.2, 0.5, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.6, 0.5, 'x[3] <= 1.65\nentropy = 0.995\nsamples = 81\nvalue = [0, 44, 37]'),
#  Text(0.4, 0.16666666666666666, 'entropy = 0.42\nsamples = 47\nvalue = [0, 43, 4]'),
#  Text(0.8, 0.16666666666666666, 'entropy = 0.191\nsamples = 34\nvalue = [0, 1, 33]')]

# %% [markdown]
# ##Arbol 5

# %% [markdown]
# *Test Size: 0.6*
#
# *Criterio: Gini*
#
# *Profundidad: 5*
#
# *Variables mas importente: *
# 1.   Petal Length <= 2.45
# 2.   Petal Width <= 1.55
# 3.   Petal Length <= 4.85

# %%
tree.plot_tree(clf_gini_PROFUNDIDAD_5_06)
# Out:
# [Text(0.3333333333333333, 0.875, 'x[2] <= 2.45\ngini = 0.663\nsamples = 60\nvalue = [19, 23, 18]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 19\nvalue = [19, 0, 0]'),
#  Text(0.5, 0.625, 'x[3] <= 1.55\ngini = 0.493\nsamples = 41\nvalue = [0, 23, 18]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 22\nvalue = [0, 22, 0]'),
#  Text(0.6666666666666666, 0.375, 'x[2] <= 4.85\ngini = 0.1\nsamples = 19\nvalue = [0, 1, 18]'),
#  Text(0.5, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16]')]

# %% [markdown]
# ##Arbol 6

# %% [markdown]
# *Test Size: 0.6*
#
# *Criterio: Gini*
#
# *Profundidad: 2*
#
# *Variables mas importente: *
# 1.   Petal Length <= 2.45
# 2.   Petal Width <= 1.55

# %%
tree.plot_tree(clf_gini_PROFUNDIDAD_2_06)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 2.45\ngini = 0.663\nsamples = 60\nvalue = [19, 23, 18]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 19\nvalue = [19, 0, 0]'),
#  Text(0.6, 0.5, 'x[3] <= 1.55\ngini = 0.493\nsamples = 41\nvalue = [0, 23, 18]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 22\nvalue = [0, 22, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.1\nsamples = 19\nvalue = [0, 1, 18]')]

# %% [markdown]
# ##Arbol 7

# %% [markdown]
# *Test Size: 0.6*
#
# *Criterio: Entropia*
#
# *Profundidad: 5*
#
# *Variables mas importente: *
# 1.   Petal Length <= 2.45
# 2.   Petal Width <= 1.55
# 3.   Petal Length <= 4.85

# %%
tree.plot_tree(clf_entropy_PROFUNDIDAD_5_06)
# Out:
# [Text(0.3333333333333333, 0.875, 'x[2] <= 2.45\nentropy = 1.577\nsamples = 60\nvalue = [19, 23, 18]'),
#  Text(0.16666666666666666, 0.625, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0, 0]'),
#  Text(0.5, 0.625, 'x[3] <= 1.55\nentropy = 0.989\nsamples = 41\nvalue = [0, 23, 18]'),
#  Text(0.3333333333333333, 0.375, 'entropy = 0.0\nsamples = 22\nvalue = [0, 22, 0]'),
#  Text(0.6666666666666666, 0.375, 'x[2] <= 4.85\nentropy = 0.297\nsamples = 19\nvalue = [0, 1, 18]'),
#  Text(0.5, 0.125, 'entropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.8333333333333334, 0.125, 'entropy = 0.0\nsamples = 16\nvalue = [0, 0, 16]')]

# %% [markdown]
# ##Arbol 8

# %% [markdown]
# *Test Size: 0.6*
#
# *Criterio: Entropia*
#
# *Profundidad: 2*
#
#
# *Variables mas importente: *
# 1.  Petal Length <= 2.45
# 2.  Petal Width <= 1.55

# %%
tree.plot_tree(clf_entropy_PROFUNDIDAD_2_06)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 2.45\nentropy = 1.577\nsamples = 60\nvalue = [19, 23, 18]'),
#  Text(0.2, 0.5, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0, 0]'),
#  Text(0.6, 0.5, 'x[3] <= 1.55\nentropy = 0.989\nsamples = 41\nvalue = [0, 23, 18]'),
#  Text(0.4, 0.16666666666666666, 'entropy = 0.0\nsamples = 22\nvalue = [0, 22, 0]'),
#  Text(0.8, 0.16666666666666666, 'entropy = 0.297\nsamples = 19\nvalue = [0, 1, 18]')]

# %% [markdown]
# ##Arbol 9

# %% [markdown]
# *Test Size: 0.3*
#
# *Criterio: Gini*
#
# *Profundidad: 3*
#
#
# *Variables mas importente: *
# 1.  Petal Length <= 2.45
# 2.  Petal Width <= 1.55

# %%
tree.plot_tree(best_model)
# Out:
# [Text(0.375, 0.875, 'x[3] <= 0.75\ngini = 0.664\nsamples = 105\nvalue = [34, 32, 39]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.5, 0.625, 'x[2] <= 4.95\ngini = 0.495\nsamples = 71\nvalue = [0, 32, 39]'),
#  Text(0.25, 0.375, 'x[3] <= 1.65\ngini = 0.161\nsamples = 34\nvalue = [0, 31, 3]'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.375, 0.125, 'gini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.75, 0.375, 'x[2] <= 5.05\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]'),
#  Text(0.625, 0.125, 'gini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]')]

# %% [markdown]
# ## Respuesta final Arboles

# %% [markdown]
# (1)**En todos los analisis realizados, tanto variando el criterio de medicion de la impureza, como la profundidad del arbol y el porcentaje de datos para el test de analisis, se encuentra que la variable mas importnate y mas determinante es el PETHAL LENGTH, especialmente cuando este mide menos de 2.45, lo cual tiene sentido ya que hay una gran cantidad de datos que presentan esta caracteristica y que, ademas, pertenecen a una sola clase. Por otro lado, la segunda variable o caracteristica mas importnate, y que se repite tambien en todos los analisis, es el Petal Width, el cual sirve muy bien para clasificar en el valor de 1.65 (aunque este valor para la clasificación es reemplazado por 1.55 cuando se analiza con un Test Split de 0.6, lo cual tiene sentido que pueda ocurrir, tal y como se explica en el punto 3)**
#
# (2) **Por otro lado, si se analiza y observa un arbol de mayor profundidad, como en los analizados de profundidad 5, es posible observar que en ramificaciones mas profundas vuelve a aparecer la variablede Pethal Length (aunque con menor dimension) por sobre otros variables analizadas que no alcanzan a entrar al arbol (como lo son por ejemplo el Sepal Length yel Petal Width). Este segundo punto, aunque apalancado principalmente por el punto 1, sirve para argumentar que la variable mas importante para la clasificación de este tipo de flores es el Pethal Length**
#
#
# (3)**Teniendo en consideracion el Criterio de medicion, la Profundidad y el Test Split, no se observa mayor diferencia en los analisis y resultados cuando se varia un solo elemento a la vez, salvo en el caso en que se analiza una profundidad de 5 entre un test split de 0.2 y otro de 0.6, en donde se observa que se pierde una rama del arbol en la tercera ramificación  a la izquierda (la variable de Pethal Width<= 4.95 deja de ser relevante). Lo cual tiene sentido que pueda ocurrir ya que se estan utilizando menos datos para el entrenamiento y algunas variables o caracteristicas mas determinantes pudiesen quedar fuera del analisis y quedar reservadas para el Test de Analisis.**

# %% [markdown]
# #**2A Evaluación de modelos**

# %% [markdown]
# Este modelo se basa en la documentacion de scikit learn y se han realizado consultas a chatGPT para mejorar el rendimiento del codigo ya que al usar un dataset tan grande en primera instancia podria tardar hasta 3 horas en dar los resultados. Ahora solo demora 3 min aproximadamente.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Cargar datos
#https://drive.google.com/file/d/1b-3gnKTAzbZHRPHnnd5vd9ua9OSS3twI/view?usp=sharing
# !gdown 1b-3gnKTAzbZHRPHnnd5vd9ua9OSS3twI
df = pd.read_csv('us_stocks_indicators.csv')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1b-3gnKTAzbZHRPHnnd5vd9ua9OSS3twI
# To: /content/us_stocks_indicators.csv
# 100% 40.0M/40.0M [00:00<00:00, 149MB/s]

# %%
# Separar características (X) y variable objetivo (Y)
X = df.drop(columns=['Price Var'])
Y = df['Price Var']

# Dividir datos en conjuntos de entrenamiento y prueba
# Como tenemos un conjunto de datos demasiado grande solo utilizaremos el 10% de los datos (test_size=0.1)
# Utilizamos random_state=0 para que nuestras pruebas sean replicables
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=0)

# Definir el modelo de ensamblaje de regresión (Random Forest Regressor)
model = RandomForestRegressor(random_state=0)

# Definir los hiperparámetros a ajustar utilizando Grid Search Cross-Validation
# Realizaremos pruebas con 1, 2, 3, 4, 5 y 6 arboles de profundidad 5, 10 y 15 (en total 6*3=18 combinaciones diferentes de hiperparámetros)
param_grid = {'n_estimators': [1, 2, 3, 4, 5, 6],
              'max_depth': [5, 10, 15]}

#Usamos validacion cruzada con GridSearchCV donde cv=3 ya que nuestro data set es demasiado grande
#Dividimos el set de datos en 3 partes (cv=3) (18*3)
#Cada combinación de hiperparámetros se evaluará 3 veces, lo que significa que el modelo se ajustará y evaluará 18*3 = 54 veces
grid_search = GridSearchCV(model, param_grid, cv=3, scoring='neg_mean_squared_error')
grid_search.fit(X_train, Y_train)

# Obtener los mejores hiperparámetros encontrados
best_params = grid_search.best_params_

# Entrenar el modelo con los mejores hiperparámetros
best_model = RandomForestRegressor(**best_params, random_state=0)
best_model.fit(X_train, Y_train)

# Realizar predicciones en el conjunto de prueba
predictions = best_model.predict(X_test)

# Calcular métricas de evaluación
mse = mean_squared_error(Y_test, predictions)
r2 = r2_score(Y_test, predictions)

print(f'MSE: {mse}')
print(f'R²: {r2}')
print(f'Best Parameters: {best_params}')
# Out:
# MSE: 787.7881482750173
# R²: 0.5777090110437422
# Best Parameters: {'max_depth': 5, 'n_estimators': 6}

# %% [markdown]
# Error Cuadrático Medio (MSE):
#
# 787.788: Este valor mide la media de los errores al cuadrado entre las predicciones del modelo y los valores reales. Un MSE más bajo indica mejores predicciones. En este caso, el MSE de 787.788 significa que las predicciones del modelo, en promedio, tienen un error cuadrático medio de 787.788 unidades respecto a los valores reales.
# Coeficiente de Determinación (R²):
#
# 0.5777: Este valor indica qué tan bien las variables independientes explican la variabilidad de la variable dependiente. Un R² de 0.5777 significa que el modelo explica aproximadamente el 57.77% de la variabilidad de los datos. Aunque es un buen comienzo, todavía hay un 42.23% de la variabilidad que el modelo no explica.

# %% [markdown]
# #2B

# %% [markdown]
# Este codigo se basa en al documentación de scikit Learn y se han hecho consultas a chatgpt para mejorar los graficos. Tambien se han utilizado los modelos vistos en clases de arboles

# %%
import pandas as pd
import numpy as np
import os
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
#Agregamos los datos
#https://drive.google.com/file/d/1b-3gnKTAzbZHRPHnnd5vd9ua9OSS3twI/view?usp=sharing
# !gdown 1b-3gnKTAzbZHRPHnnd5vd9ua9OSS3twI
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1b-3gnKTAzbZHRPHnnd5vd9ua9OSS3twI
# To: /content/us_stocks_indicators.csv
# 100% 40.0M/40.0M [00:00<00:00, 153MB/s]

# %%
df = pd.read_csv('us_stocks_indicators.csv')

# Contar cuántas filas tienen al menos un valor nulo
num_rows_with_na = df.isnull().any(axis=1).sum()
print(f'Número de filas con al menos un valor nulo: {num_rows_with_na}')

df.head()
# Out:
# Número de filas con al menos un valor nulo: 0
#    Year   Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0  2014  3.878567       -0.129934         1.790827      7.800696
# 1  2014  0.200522       -0.108851         0.143151      0.275383
# 2  2014  0.432598       -0.105983         0.346556      0.498363
# 3  2014  0.528338       -0.085962         0.628055      0.089929
# 4  2014  5.767776       -0.118091         3.321925      9.931729
#
#    R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 0     -0.176558      9.122478            7.021603          7.492154
# 1     -0.176558      0.487538            0.290552          0.178611
# 2      0.082470      0.500981            0.332736          0.710699
# 3     -0.176558      0.032375           -0.089120          0.427129
# 4     -0.176558     13.815935           10.011302          7.390123
#
#    Interest Expense  ...  Receivables growth  Inventory Growth  Asset Growth  \
# ...

# %%
#Esta es la columna de datos exluimos la variable objetivo Class
df_data = df.drop(columns=["Class"])
df_data.head()
# Out:
#    Year   Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0  2014  3.878567       -0.129934         1.790827      7.800696
# 1  2014  0.200522       -0.108851         0.143151      0.275383
# 2  2014  0.432598       -0.105983         0.346556      0.498363
# 3  2014  0.528338       -0.085962         0.628055      0.089929
# 4  2014  5.767776       -0.118091         3.321925      9.931729
#
#    R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 0     -0.176558      9.122478            7.021603          7.492154
# 1     -0.176558      0.487538            0.290552          0.178611
# 2      0.082470      0.500981            0.332736          0.710699
# 3     -0.176558      0.032375           -0.089120          0.427129
# 4     -0.176558     13.815935           10.011302          7.390123
#
#    Interest Expense  ...  3Y Dividend per Share Growth (per Share)  \
# 0          2.218515  ...                                  0.324440
# ...

# %%
#Esta es la variable objetivo
df_target = df['Class'].copy()
df_target.name = 'Class'
df_target.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Class, dtype: int64

# %%
from sklearn.decomposition import PCA



# Creamos nuestro objeto PCA y le indicamos cuántas dimensiones retornar
# (notar que se pueden mantener todos los componentes)
pca = PCA(n_components=2)
#projected = pca.fit_transform(df.iloc[:, 1:])
projected = pca.fit_transform(df_data)
plt.scatter(
    projected[:, 0],
    projected[:, 1],
    c=df_target,
    edgecolor="none",
    alpha=0.5,
    cmap=colormaps["nipy_spectral"].resampled(len(set(df_target))),
)
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.colorbar()
plt.show()
#Este grafico es el resultado de usar PCA para reducir dimensionalidad y luego usar un modelo de machine learning
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-523a44313d41> in <cell line: 9>()
#       7 pca = PCA(n_components=2)
#       8 #projected = pca.fit_transform(df.iloc[:, 1:])
# ----> 9 projected = pca.fit_transform(df_data)
#      10 plt.scatter(
#      11     projected[:, 0],
#
# NameError: name 'df_data' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
# Haremos el split al mismo tiempo en las features y las etiquetas
# X_train, X_test, y_train, y_test
train_features, test_features, train_classes, test_classes = train_test_split(
    df_data, df_target, test_size=0.1, random_state=0
)

# %% [markdown]
# A continuacion los dataframes con caracteristicas
# **train_features, test_features, train_classes, test_classes**

# %%
train_features
# Out:
#        Year   Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 4041   2016 -0.320785        0.110159        -0.259360     -0.363254
# 1669   2015 -0.296627        0.052220        -0.260997     -0.282270
# 5280   2016 -0.307063       -0.014747        -0.260997     -0.315465
# 641    2014  0.102130       -0.093610         0.216202     -0.222575
# 8242   2017 -0.263628       -0.074385        -0.251226     -0.202063
# ...     ...       ...             ...              ...           ...
# 4859   2016 -0.312983        0.127100        -0.257445     -0.343290
# 3264   2015 -0.320080       -0.126057        -0.260155     -0.358999
# 9845   2018 -0.288202       -0.088989        -0.233735     -0.324522
# 10799  2018 -0.123170       -0.002904        -0.061814     -0.235043
# 2732   2015 -0.314787       -0.461051        -0.249979     -0.367936
#
#        R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# ...

# %%
test_features
# Out:
#        Year   Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 5452   2016 -0.315207       -0.083997        -0.260997     -0.341367
# 9099   2018  0.805353       -0.114427         0.645834      0.925968
# 11522  2018 -0.320124        0.030393        -0.259906     -0.359770
# 5178   2016 -0.294880        0.139208        -0.260997     -0.276715
# 5480   2016  0.261898       -0.124889         0.203642      0.317388
# ...     ...       ...             ...              ...           ...
# 6676   2017  1.474974       -0.107045         1.108950      1.882837
# 5536   2016 -0.292923       -0.122924        -0.229070     -0.351352
# 2894   2015 -0.318607        0.050999        -0.260997     -0.352179
# 8898   2018  0.402486       -0.112675         0.379795      0.318404
# 1861   2015 -0.309228       -0.101469        -0.252423     -0.344063
#
#        R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# ...

# %%
train_classes
# Out:
# 4041     1
# 1669     0
# 5280     0
# 641      1
# 8242     1
#         ..
# 4859     1
# 3264     1
# 9845     1
# 10799    1
# 2732     1
# Name: Class, Length: 10409, dtype: int64

# %%
test_classes
# Out:
# 5452     1
# 9099     1
# 11522    0
# 5178     0
# 5480     1
#         ..
# 6676     1
# 5536     1
# 2894     1
# 8898     1
# 1861     1
# Name: Class, Length: 1157, dtype: int64

# %% [markdown]
# Aqui aplicamos un modelo de Knn vecinos y evaluamos el modelo con una matriz de confusión dando como resultado su acurracy

# %%
from sklearn.neighbors import KNeighborsClassifier
import sklearn.metrics as metrics


# Definimos y ajustamos nuestro clasificador sobre los datos de entrenamiento
classifier = KNeighborsClassifier(n_neighbors=1)
classifier.fit(train_features, train_classes)

# Usamos el clasificador para predecir sobre los datos de test
predicted = classifier.predict(test_features)

expected = test_classes
print("Confusion matrix:\n%s" % metrics.confusion_matrix(expected, predicted))
print()
print("Accuracy: %s" % metrics.balanced_accuracy_score(expected, predicted))
# Out:
# Confusion matrix:
# [[475  16]
#  [  9 657]]
#
# Accuracy: 0.97694996422084

# %% [markdown]
# En este codigo usamos un clasificados para determinar que modelo nos entrega los mejores resultados en cuanto acurracy evaluando los k nn vecinos cercanos y determinado cual es el mejor rendimiento

# %%
K = 10
max_accuracy = 0
best_neighbors = 0
for n_neighbors in range(1, K + 1):
    print(f"Evaluando rendimiento para {n_neighbors} vecinos")
    # Definimos y ajustamos nuestro clasificador sobre los datos de entrenamiento
    classifier = KNeighborsClassifier(n_neighbors=n_neighbors).fit(
        train_features, train_classes
    )
    # Usamos el clasificador para predecir sobre los datos de test
    predicted = classifier.predict(test_features)
    accuracy = metrics.balanced_accuracy_score(expected, predicted)
    print(f"K={n_neighbors}: {accuracy:.2f}")
    if accuracy > max_accuracy:
        max_accuracy = accuracy
        best_neighbors = n_neighbors
print(
    f"El mejor rendimiento se alcanza con {best_neighbors} vecinos "
    f"junto con un accuracy de {max_accuracy}."
)
# Out:
# Evaluando rendimiento para 1 vecinos
# K=1: 0.98
# Evaluando rendimiento para 2 vecinos
# K=2: 0.97
# Evaluando rendimiento para 3 vecinos
# K=3: 0.98
# Evaluando rendimiento para 4 vecinos
# K=4: 0.98
# Evaluando rendimiento para 5 vecinos
# K=5: 0.99
# Evaluando rendimiento para 6 vecinos
# K=6: 0.99
# Evaluando rendimiento para 7 vecinos
# K=7: 0.99
# Evaluando rendimiento para 8 vecinos
# K=8: 0.99
# Evaluando rendimiento para 9 vecinos
# K=9: 0.99
# Evaluando rendimiento para 10 vecinos
# K=10: 0.99
# El mejor rendimiento se alcanza con 9 vecinos junto con un accuracy de 0.9929236772413962.
