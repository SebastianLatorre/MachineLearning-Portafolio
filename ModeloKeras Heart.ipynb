# %% [markdown]
# # Clasificador simple sobre datos estructurados
#
# Nos basaremos el tutorial [Imbalanced classification: credit card fraud detection](https://keras.io/examples/structured_data/imbalanced_classification/), uno de los [ejemplos de Keras sobre datos estructurados](https://keras.io/examples/structured_data/), para utilizar Keras sobre datos de un dominio con el que estamos famirializados.
#
# Utilizaremos el dataset [Kaggle Credit Card Fraud Detection](https://www.kaggle.com/mlg-ulb/creditcardfraud/) para demostrar cómo entrenar un clasificador simple en Keras sobre datos con clases desbalanceadas.
#
#
# Realizaremos los siguientes pasos:
#
# 1. Carga del dataset
# 2. Preparación del conjunto de validación
# 4. Análisis del "desbalance" de clases
# 5. Estandarización (manual) de datos
# 6. Definición del modelo
# 7. Entrenamiento del modelo

# %% [markdown]
# ## 1. Carga de datos

# %%
# import os

# # Crear el directorio ./data si no existe
# os.makedirs('./data', exist_ok=True)

# # Descargar el archivo con gdown
# !pip install gdown
# !gdown 1TldKEcayYQDOghWTop67-jOeu05YrRCs -O ./data/creditcard.csv.zip

# # Descomprimir el archivo
# import zipfile

# with zipfile.ZipFile('./data/creditcard.csv.zip', 'r') as zip_ref:
#     zip_ref.extractall('./data/')

# %% [markdown]
# https://drive.google.com/file/d/11jIiAfoZNLA9pvGp6qEtaR2E6EuxYJip/view?usp=sharing

# %%
import os

# Crear el directorio ./data si no existe
os.makedirs('./data', exist_ok=True)

# Descargar el archivo con gdown
# !pip install gdown
# !gdown 11jIiAfoZNLA9pvGp6qEtaR2E6EuxYJip -O ./data/SAheart.csv

# # Descomprimir el archivo
# import zipfile

# with zipfile.ZipFile('./data/creditcard.csv.zip', 'r') as zip_ref:
#     zip_ref.extractall('./data/')
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.15.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=11jIiAfoZNLA9pvGp6qEtaR2E6EuxYJip
# To: /content/data/SAheart.csv
# 100% 22.2k/22.2k [00:00<00:00, 43.1MB/s]

# %%
from pathlib import Path

import numpy as np
import pandas as pd


np.random.seed(0)

PATH = Path("data", "SAheart.csv")
df = pd.read_csv(PATH)

df["famhist"] = df["famhist"].replace({"Absent":0, "Present":1})
df["chd"] = df["chd"].replace({"No":0, "Si":1})

df.head()

features = np.array(df.iloc[:, :-1], dtype="float32")
targets = np.array(df.iloc[:, [-1]], dtype="uint8")

del df

print("features.shape:", features.shape)
print("targets.shape:", targets.shape)
# Out:
# features.shape: (462, 9)
# targets.shape: (462, 1)

# %% [markdown]
# ## 2. Preparación de conjunto de validación

# %%
num_val_samples = int(len(features) * 0.2)
train_features = features[:-num_val_samples]
train_targets = targets[:-num_val_samples]
val_features = features[-num_val_samples:]
val_targets = targets[-num_val_samples:]

print("Number of training samples:", len(train_features))
print("Number of validation samples:", len(val_features))
# Out:
# Number of training samples: 370
# Number of validation samples: 92

# %% [markdown]
# ## 3. Análisis del "desbalance" de clases

# %%
counts = pd.Series(train_targets.flatten()).value_counts()
print(counts)
# Out:
# 0    238
# 1    132
# Name: count, dtype: int64

# %%
print(
    f"Number of positive samples in training data: {counts.loc[1]} "
    f"({100 * float(counts.loc[1]) / len(train_targets):.2f}% of total)"
)
# Out:
# Number of positive samples in training data: 132 (35.68% of total)

# %%
weight_for_0 = 1.0 / counts.loc[0]
print(f"Weight for label 0: {weight_for_0}")
weight_for_1 = 1.0 / counts.loc[1]
print(f"Weight for label 1: {weight_for_1}")
# Out:
# Weight for label 0: 0.004201680672268907
# Weight for label 1: 0.007575757575757576

# %% [markdown]
# ## 4. Estandarización (manual) de datos

# %%
mean = np.mean(train_features, axis=0)
std = np.std(train_features, axis=0)

train_features = (train_features - mean) / std
val_features = (val_features - mean) / std

# %% [markdown]
# ## 5. Definición de un modelo de clasificación binaria

# %%
train_features.shape[1:]
# Out:
# (9,)

# %%
import keras

keras.utils.set_random_seed(0)


# Equivalente en scikit: MLPClassifier(hidden_layer_sizes=(256,))
model = keras.Sequential(
    [
        keras.Input(shape=train_features.shape[1:]),  # 30
        keras.layers.Dense(256, activation="relu"),  # [X, 16, 64, 256]
        # keras.layers.Dense(256, activation="relu"),
        # keras.layers.Dropout(0.3),
        # keras.layers.Dense(256, activation="relu"),
        # keras.layers.Dropout(0.3),
        keras.layers.Dense(1, activation="sigmoid"),  # 1
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2560
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 2817 (11.00 KB)
# Trainable params: 2817 (11.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## 6. Entrenando el modelo con el argumento `class_weight`

# %%
# https://keras.io/api/metrics/
metrics = [
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(optimizer=keras.optimizers.Adam(1e-2), loss="binary_crossentropy", metrics=metrics)

callbacks = [keras.callbacks.ModelCheckpoint("checkpoints/fraud_model_at_epoch_{epoch}.keras")]
class_weight = {0: weight_for_0, 1: weight_for_1}

model.fit(
    train_features,
    train_targets,
    batch_size=2048,
    epochs=30,
    verbose=2,
    callbacks=callbacks,
    validation_data=(val_features, val_targets),
    class_weight=class_weight,  # TODO: Comparar modelo sin esta opción
)
# Out:
# Epoch 1/30
# 1/1 - 2s - loss: 0.0038 - fn: 104.0000 - fp: 27.0000 - tn: 211.0000 - tp: 28.0000 - precision: 0.5091 - recall: 0.2121 - val_loss: 0.5942 - val_fn: 8.0000 - val_fp: 23.0000 - val_tn: 41.0000 - val_tp: 20.0000 - val_precision: 0.4651 - val_recall: 0.7143 - 2s/epoch - 2s/step
# Epoch 2/30
# 1/1 - 0s - loss: 0.0033 - fn: 43.0000 - fp: 81.0000 - tn: 157.0000 - tp: 89.0000 - precision: 0.5235 - recall: 0.6742 - val_loss: 0.6051 - val_fn: 6.0000 - val_fp: 26.0000 - val_tn: 38.0000 - val_tp: 22.0000 - val_precision: 0.4583 - val_recall: 0.7857 - 114ms/epoch - 114ms/step
# Epoch 3/30
# 1/1 - 0s - loss: 0.0031 - fn: 26.0000 - fp: 94.0000 - tn: 144.0000 - tp: 106.0000 - precision: 0.5300 - recall: 0.8030 - val_loss: 0.6186 - val_fn: 4.0000 - val_fp: 27.0000 - val_tn: 37.0000 - val_tp: 24.0000 - val_precision: 0.4706 - val_recall: 0.8571 - 105ms/epoch - 105ms/step
# Epoch 4/30
# 1/1 - 0s - loss: 0.0031 - fn: 24.0000 - fp: 95.0000 - tn: 143.0000 - tp: 108.0000 - precision: 0.5320 - recall: 0.8182 - val_loss: 0.6140 - val_fn: 4.0000 - val_fp: 26.0000 - val_tn: 38.0000 - val_tp: 24.0000 - val_precision: 0.4800 - val_recall: 0.8571 - 135ms/epoch - 135ms/step
# Epoch 5/30
# 1/1 - 0s - loss: 0.0030 - fn: 24.0000 - fp: 88.0000 - tn: 150.0000 - tp: 108.0000 - precision: 0.5510 - recall: 0.8182 - val_loss: 0.5969 - val_fn: 4.0000 - val_fp: 23.0000 - val_tn: 41.0000 - val_tp: 24.0000 - val_precision: 0.5106 - val_recall: 0.8571 - 143ms/epoch - 143ms/step
# Epoch 6/30
# 1/1 - 0s - loss: 0.0030 - fn: 24.0000 - fp: 80.0000 - tn: 158.0000 - tp: 108.0000 - precision: 0.5745 - recall: 0.8182 - val_loss: 0.5782 - val_fn: 6.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 22.0000 - val_precision: 0.5238 - val_recall: 0.7857 - 94ms/epoch - 94ms/step
# Epoch 7/30
# 1/1 - 0s - loss: 0.0029 - fn: 31.0000 - fp: 78.0000 - tn: 160.0000 - tp: 101.0000 - precision: 0.5642 - recall: 0.7652 - val_loss: 0.5657 - val_fn: 7.0000 - val_fp: 17.0000 - val_tn: 47.0000 - val_tp: 21.0000 - val_precision: 0.5526 - val_recall: 0.7500 - 89ms/epoch - 89ms/step
# Epoch 8/30
# 1/1 - 0s - loss: 0.0029 - fn: 36.0000 - fp: 75.0000 - tn: 163.0000 - tp: 96.0000 - precision: 0.5614 - recall: 0.7273 - val_loss: 0.5605 - val_fn: 7.0000 - val_fp: 16.0000 - val_tn: 48.0000 - val_tp: 21.0000 - val_precision: 0.5676 - val_recall: 0.7500 - 129ms/epoch - 129ms/step
# Epoch 9/30
# 1/1 - 0s - loss: 0.0029 - fn: 39.0000 - fp: 69.0000 - tn: 169.0000 - tp: 93.0000 - precision: 0.5741 - recall: 0.7045 - val_loss: 0.5597 - val_fn: 8.0000 - val_fp: 15.0000 - val_tn: 49.0000 - val_tp: 20.0000 - val_precision: 0.5714 - val_recall: 0.7143 - 104ms/epoch - 104ms/step
# Epoch 10/30
# 1/1 - 0s - loss: 0.0029 - fn: 38.0000 - fp: 68.0000 - tn: 170.0000 - tp: 94.0000 - precision: 0.5802 - recall: 0.7121 - val_loss: 0.5604 - val_fn: 9.0000 - val_fp: 15.0000 - val_tn: 49.0000 - val_tp: 19.0000 - val_precision: 0.5588 - val_recall: 0.6786 - 84ms/epoch - 84ms/step
# Epoch 11/30
# 1/1 - 0s - loss: 0.0028 - fn: 39.0000 - fp: 66.0000 - tn: 172.0000 - tp: 93.0000 - precision: 0.5849 - recall: 0.7045 - val_loss: 0.5619 - val_fn: 9.0000 - val_fp: 15.0000 - val_tn: 49.0000 - val_tp: 19.0000 - val_precision: 0.5588 - val_recall: 0.6786 - 130ms/epoch - 130ms/step
# Epoch 12/30
# 1/1 - 0s - loss: 0.0028 - fn: 36.0000 - fp: 67.0000 - tn: 171.0000 - tp: 96.0000 - precision: 0.5890 - recall: 0.7273 - val_loss: 0.5641 - val_fn: 9.0000 - val_fp: 17.0000 - val_tn: 47.0000 - val_tp: 19.0000 - val_precision: 0.5278 - val_recall: 0.6786 - 151ms/epoch - 151ms/step
# Epoch 13/30
# 1/1 - 0s - loss: 0.0028 - fn: 32.0000 - fp: 70.0000 - tn: 168.0000 - tp: 100.0000 - precision: 0.5882 - recall: 0.7576 - val_loss: 0.5674 - val_fn: 8.0000 - val_fp: 17.0000 - val_tn: 47.0000 - val_tp: 20.0000 - val_precision: 0.5405 - val_recall: 0.7143 - 170ms/epoch - 170ms/step
# Epoch 14/30
# 1/1 - 0s - loss: 0.0027 - fn: 29.0000 - fp: 72.0000 - tn: 166.0000 - tp: 103.0000 - precision: 0.5886 - recall: 0.7803 - val_loss: 0.5712 - val_fn: 8.0000 - val_fp: 16.0000 - val_tn: 48.0000 - val_tp: 20.0000 - val_precision: 0.5556 - val_recall: 0.7143 - 101ms/epoch - 101ms/step
# Epoch 15/30
# 1/1 - 0s - loss: 0.0027 - fn: 25.0000 - fp: 75.0000 - tn: 163.0000 - tp: 107.0000 - precision: 0.5879 - recall: 0.8106 - val_loss: 0.5744 - val_fn: 8.0000 - val_fp: 18.0000 - val_tn: 46.0000 - val_tp: 20.0000 - val_precision: 0.5263 - val_recall: 0.7143 - 92ms/epoch - 92ms/step
# Epoch 16/30
# 1/1 - 0s - loss: 0.0027 - fn: 24.0000 - fp: 77.0000 - tn: 161.0000 - tp: 108.0000 - precision: 0.5838 - recall: 0.8182 - val_loss: 0.5758 - val_fn: 8.0000 - val_fp: 19.0000 - val_tn: 45.0000 - val_tp: 20.0000 - val_precision: 0.5128 - val_recall: 0.7143 - 113ms/epoch - 113ms/step
# Epoch 17/30
# 1/1 - 0s - loss: 0.0027 - fn: 22.0000 - fp: 74.0000 - tn: 164.0000 - tp: 110.0000 - precision: 0.5978 - recall: 0.8333 - val_loss: 0.5754 - val_fn: 8.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 20.0000 - val_precision: 0.5000 - val_recall: 0.7143 - 97ms/epoch - 97ms/step
# Epoch 18/30
# 1/1 - 0s - loss: 0.0027 - fn: 23.0000 - fp: 75.0000 - tn: 163.0000 - tp: 109.0000 - precision: 0.5924 - recall: 0.8258 - val_loss: 0.5737 - val_fn: 8.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 20.0000 - val_precision: 0.5000 - val_recall: 0.7143 - 112ms/epoch - 112ms/step
# Epoch 19/30
# 1/1 - 0s - loss: 0.0027 - fn: 24.0000 - fp: 72.0000 - tn: 166.0000 - tp: 108.0000 - precision: 0.6000 - recall: 0.8182 - val_loss: 0.5716 - val_fn: 8.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 20.0000 - val_precision: 0.5000 - val_recall: 0.7143 - 221ms/epoch - 221ms/step
# Epoch 20/30
# 1/1 - 0s - loss: 0.0026 - fn: 25.0000 - fp: 66.0000 - tn: 172.0000 - tp: 107.0000 - precision: 0.6185 - recall: 0.8106 - val_loss: 0.5705 - val_fn: 8.0000 - val_fp: 19.0000 - val_tn: 45.0000 - val_tp: 20.0000 - val_precision: 0.5128 - val_recall: 0.7143 - 102ms/epoch - 102ms/step
# Epoch 21/30
# 1/1 - 0s - loss: 0.0026 - fn: 26.0000 - fp: 61.0000 - tn: 177.0000 - tp: 106.0000 - precision: 0.6347 - recall: 0.8030 - val_loss: 0.5710 - val_fn: 8.0000 - val_fp: 18.0000 - val_tn: 46.0000 - val_tp: 20.0000 - val_precision: 0.5263 - val_recall: 0.7143 - 106ms/epoch - 106ms/step
# Epoch 22/30
# 1/1 - 0s - loss: 0.0026 - fn: 25.0000 - fp: 59.0000 - tn: 179.0000 - tp: 107.0000 - precision: 0.6446 - recall: 0.8106 - val_loss: 0.5731 - val_fn: 9.0000 - val_fp: 18.0000 - val_tn: 46.0000 - val_tp: 19.0000 - val_precision: 0.5135 - val_recall: 0.6786 - 99ms/epoch - 99ms/step
# Epoch 23/30
# 1/1 - 0s - loss: 0.0026 - fn: 25.0000 - fp: 56.0000 - tn: 182.0000 - tp: 107.0000 - precision: 0.6564 - recall: 0.8106 - val_loss: 0.5764 - val_fn: 9.0000 - val_fp: 17.0000 - val_tn: 47.0000 - val_tp: 19.0000 - val_precision: 0.5278 - val_recall: 0.6786 - 111ms/epoch - 111ms/step
# Epoch 24/30
# 1/1 - 0s - loss: 0.0026 - fn: 25.0000 - fp: 55.0000 - tn: 183.0000 - tp: 107.0000 - precision: 0.6605 - recall: 0.8106 - val_loss: 0.5802 - val_fn: 9.0000 - val_fp: 17.0000 - val_tn: 47.0000 - val_tp: 19.0000 - val_precision: 0.5278 - val_recall: 0.6786 - 92ms/epoch - 92ms/step
# Epoch 25/30
# 1/1 - 0s - loss: 0.0025 - fn: 25.0000 - fp: 56.0000 - tn: 182.0000 - tp: 107.0000 - precision: 0.6564 - recall: 0.8106 - val_loss: 0.5847 - val_fn: 9.0000 - val_fp: 17.0000 - val_tn: 47.0000 - val_tp: 19.0000 - val_precision: 0.5278 - val_recall: 0.6786 - 122ms/epoch - 122ms/step
# Epoch 26/30
# 1/1 - 0s - loss: 0.0025 - fn: 26.0000 - fp: 56.0000 - tn: 182.0000 - tp: 106.0000 - precision: 0.6543 - recall: 0.8030 - val_loss: 0.5897 - val_fn: 9.0000 - val_fp: 17.0000 - val_tn: 47.0000 - val_tp: 19.0000 - val_precision: 0.5278 - val_recall: 0.6786 - 240ms/epoch - 240ms/step
# Epoch 27/30
# 1/1 - 0s - loss: 0.0025 - fn: 26.0000 - fp: 55.0000 - tn: 183.0000 - tp: 106.0000 - precision: 0.6584 - recall: 0.8030 - val_loss: 0.5948 - val_fn: 9.0000 - val_fp: 19.0000 - val_tn: 45.0000 - val_tp: 19.0000 - val_precision: 0.5000 - val_recall: 0.6786 - 179ms/epoch - 179ms/step
# Epoch 28/30
# 1/1 - 0s - loss: 0.0025 - fn: 25.0000 - fp: 56.0000 - tn: 182.0000 - tp: 107.0000 - precision: 0.6564 - recall: 0.8106 - val_loss: 0.5998 - val_fn: 9.0000 - val_fp: 19.0000 - val_tn: 45.0000 - val_tp: 19.0000 - val_precision: 0.5000 - val_recall: 0.6786 - 194ms/epoch - 194ms/step
# Epoch 29/30
# 1/1 - 0s - loss: 0.0025 - fn: 26.0000 - fp: 56.0000 - tn: 182.0000 - tp: 106.0000 - precision: 0.6543 - recall: 0.8030 - val_loss: 0.6043 - val_fn: 9.0000 - val_fp: 19.0000 - val_tn: 45.0000 - val_tp: 19.0000 - val_precision: 0.5000 - val_recall: 0.6786 - 232ms/epoch - 232ms/step
# Epoch 30/30
# 1/1 - 0s - loss: 0.0025 - fn: 25.0000 - fp: 56.0000 - tn: 182.0000 - tp: 107.0000 - precision: 0.6564 - recall: 0.8106 - val_loss: 0.6081 - val_fn: 9.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 19.0000 - val_precision: 0.4872 - val_recall: 0.6786 - 354ms/epoch - 354ms/step

# %%
val_results = model.evaluate(val_features, val_targets)
# Métricas resultantes
val_results
# Out:
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6081 - fn: 9.0000 - fp: 20.0000 - tn: 44.0000 - tp: 19.0000 - precision: 0.4872 - recall: 0.6786
# [0.6081216931343079,
#  9.0,
#  20.0,
#  44.0,
#  19.0,
#  0.4871794879436493,
#  0.6785714030265808]

# %%
# Formato ordenado
pd.DataFrame([val_results], columns=model.metrics_names)
# Out:
#        loss   fn    fp    tn    tp  precision    recall
# 0  0.608122  9.0  20.0  44.0  19.0   0.487179  0.678571

# %% [markdown]
# En este punto, de las 56.961 transacciones utilizadas en el conjunto de validación, hemos:
#
# * Identificado correctamente a 64 de ellas como fraudulentas
# * Fallado en identificar 11 transacciones fraudulentas
# * Al costo de marcar incorrectamente 155 transacciones legítimas
#
# En el mundo real, probablamente se le daría más peso a la clase 1, para reflejar que los falsos negativos son más costosos que los falsos positivos.
#
# > Si nuestra tarjeta de crédito es rechazada en una compra online, esta es la razón.

# %% [markdown]
# ## 7. Serializar y deserializar un modelo en Keras

# %%
OUTPUT_PATH = "model.keras"
model.save(OUTPUT_PATH)

# %%
model_loaded = keras.models.load_model(OUTPUT_PATH)

# %%
# Formato ordenado
pd.DataFrame([model_loaded.evaluate(val_features, val_targets)], columns=model_loaded.metrics_names)
# Out:
# 3/3 [==============================] - 2s 24ms/step - loss: 0.6081 - fn: 9.0000 - fp: 20.0000 - tn: 44.0000 - tp: 19.0000 - precision: 0.4872 - recall: 0.6786
#        loss   fn    fp    tn    tp  precision    recall
# 0  0.608122  9.0  20.0  44.0  19.0   0.487179  0.678571

# %% [markdown]
# Estas métricas fueron el resultado del modelo que entrenamos (antes de serializar). Notar que son exactamente iguales a las obtenidas por el modelo que acabamos de deserializar, pues son exactamente el mismo modelo (mismos pesos):
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import tensorflow.keras as keras

# Definir los datos de ejemplo
data = {
    'sbp': [102],
    'tobacco': [0],
    'ldl': [0.98],
    'adiposity': [6.74],
    'famhist': [0],  # Cambiado 'Absent' a 0
    'typea': [13],
    'obesity': [14.7],
    'alcohol': [117.22],
    'age': [15],
}


# Crear un DataFrame con los datos
df = pd.DataFrame(data)

# # Definir la función para convertir 'chd' a 0 o 1
# def convert_chd(value):
#     return 1 if value == 'Si' else 0

# # Aplicar la conversión a la columna 'chd'
# df['chd'] = df['chd'].apply(convert_chd)

# Cargar el modelo Keras entrenado (sustituye 'modelo.keras' con el nombre real de tu archivo)
model = keras.models.load_model('model.keras')

# Realizar la predicción
predictions = model.predict(df)

# Convertir las predicciones a valores binarios (0 o 1)
threshold = 0.5  # Umbral para decidir si es 0 o 1
predictions_binary = [1 if pred > threshold else 0 for pred in predictions]

# Mostrar las predicciones
print("Predicciones:")
for pred in predictions_binary:
    print(f"CHD: {'Si' if pred == 1 else 'No'}")
# Out:
# 1/1 [==============================] - 0s 490ms/step
# Predicciones:
# CHD: No

# %%
model.fit(
    train_features,
    train_targets,
    batch_size=2048,
    epochs=30,
    verbose=2,
    callbacks=callbacks,
    validation_data=(val_features, val_targets),
    class_weight=class_weight,  # TODO: Comparar modelo sin esta opción
)
# Out:
# Epoch 1/30
# 1/1 - 5s - loss: 0.0024 - fn: 24.0000 - fp: 55.0000 - tn: 183.0000 - tp: 108.0000 - precision: 0.6626 - recall: 0.8182 - val_loss: 0.6115 - val_fn: 9.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 19.0000 - val_precision: 0.4750 - val_recall: 0.6786 - 5s/epoch - 5s/step
# Epoch 2/30
# 1/1 - 0s - loss: 0.0024 - fn: 24.0000 - fp: 55.0000 - tn: 183.0000 - tp: 108.0000 - precision: 0.6626 - recall: 0.8182 - val_loss: 0.6144 - val_fn: 9.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 19.0000 - val_precision: 0.4750 - val_recall: 0.6786 - 284ms/epoch - 284ms/step
# Epoch 3/30
# 1/1 - 0s - loss: 0.0024 - fn: 24.0000 - fp: 57.0000 - tn: 181.0000 - tp: 108.0000 - precision: 0.6545 - recall: 0.8182 - val_loss: 0.6173 - val_fn: 9.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 19.0000 - val_precision: 0.4750 - val_recall: 0.6786 - 249ms/epoch - 249ms/step
# Epoch 4/30
# 1/1 - 0s - loss: 0.0024 - fn: 25.0000 - fp: 56.0000 - tn: 182.0000 - tp: 107.0000 - precision: 0.6564 - recall: 0.8106 - val_loss: 0.6200 - val_fn: 11.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 17.0000 - val_precision: 0.4474 - val_recall: 0.6071 - 255ms/epoch - 255ms/step
# Epoch 5/30
# 1/1 - 0s - loss: 0.0024 - fn: 25.0000 - fp: 56.0000 - tn: 182.0000 - tp: 107.0000 - precision: 0.6564 - recall: 0.8106 - val_loss: 0.6231 - val_fn: 11.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 17.0000 - val_precision: 0.4474 - val_recall: 0.6071 - 394ms/epoch - 394ms/step
# Epoch 6/30
# 1/1 - 0s - loss: 0.0024 - fn: 24.0000 - fp: 55.0000 - tn: 183.0000 - tp: 108.0000 - precision: 0.6626 - recall: 0.8182 - val_loss: 0.6269 - val_fn: 10.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 18.0000 - val_precision: 0.4615 - val_recall: 0.6429 - 448ms/epoch - 448ms/step
# Epoch 7/30
# 1/1 - 0s - loss: 0.0023 - fn: 25.0000 - fp: 50.0000 - tn: 188.0000 - tp: 107.0000 - precision: 0.6815 - recall: 0.8106 - val_loss: 0.6315 - val_fn: 10.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 18.0000 - val_precision: 0.4615 - val_recall: 0.6429 - 268ms/epoch - 268ms/step
# Epoch 8/30
# 1/1 - 0s - loss: 0.0023 - fn: 24.0000 - fp: 50.0000 - tn: 188.0000 - tp: 108.0000 - precision: 0.6835 - recall: 0.8182 - val_loss: 0.6362 - val_fn: 10.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 18.0000 - val_precision: 0.4615 - val_recall: 0.6429 - 398ms/epoch - 398ms/step
# Epoch 9/30
# 1/1 - 0s - loss: 0.0023 - fn: 25.0000 - fp: 50.0000 - tn: 188.0000 - tp: 107.0000 - precision: 0.6815 - recall: 0.8106 - val_loss: 0.6400 - val_fn: 10.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 18.0000 - val_precision: 0.4615 - val_recall: 0.6429 - 179ms/epoch - 179ms/step
# Epoch 10/30
# 1/1 - 0s - loss: 0.0023 - fn: 25.0000 - fp: 50.0000 - tn: 188.0000 - tp: 107.0000 - precision: 0.6815 - recall: 0.8106 - val_loss: 0.6428 - val_fn: 10.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 18.0000 - val_precision: 0.4615 - val_recall: 0.6429 - 159ms/epoch - 159ms/step
# Epoch 11/30
# 1/1 - 0s - loss: 0.0023 - fn: 25.0000 - fp: 51.0000 - tn: 187.0000 - tp: 107.0000 - precision: 0.6772 - recall: 0.8106 - val_loss: 0.6442 - val_fn: 10.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 18.0000 - val_precision: 0.4615 - val_recall: 0.6429 - 235ms/epoch - 235ms/step
# Epoch 12/30
# 1/1 - 0s - loss: 0.0022 - fn: 24.0000 - fp: 49.0000 - tn: 189.0000 - tp: 108.0000 - precision: 0.6879 - recall: 0.8182 - val_loss: 0.6447 - val_fn: 11.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 17.0000 - val_precision: 0.4474 - val_recall: 0.6071 - 179ms/epoch - 179ms/step
# Epoch 13/30
# 1/1 - 0s - loss: 0.0022 - fn: 24.0000 - fp: 48.0000 - tn: 190.0000 - tp: 108.0000 - precision: 0.6923 - recall: 0.8182 - val_loss: 0.6455 - val_fn: 12.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 16.0000 - val_precision: 0.4324 - val_recall: 0.5714 - 200ms/epoch - 200ms/step
# Epoch 14/30
# 1/1 - 0s - loss: 0.0022 - fn: 25.0000 - fp: 48.0000 - tn: 190.0000 - tp: 107.0000 - precision: 0.6903 - recall: 0.8106 - val_loss: 0.6479 - val_fn: 11.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 17.0000 - val_precision: 0.4474 - val_recall: 0.6071 - 337ms/epoch - 337ms/step
# Epoch 15/30
# 1/1 - 0s - loss: 0.0022 - fn: 24.0000 - fp: 49.0000 - tn: 189.0000 - tp: 108.0000 - precision: 0.6879 - recall: 0.8182 - val_loss: 0.6520 - val_fn: 11.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 17.0000 - val_precision: 0.4474 - val_recall: 0.6071 - 314ms/epoch - 314ms/step
# Epoch 16/30
# 1/1 - 0s - loss: 0.0022 - fn: 23.0000 - fp: 49.0000 - tn: 189.0000 - tp: 109.0000 - precision: 0.6899 - recall: 0.8258 - val_loss: 0.6569 - val_fn: 11.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 17.0000 - val_precision: 0.4474 - val_recall: 0.6071 - 378ms/epoch - 378ms/step
# Epoch 17/30
# 1/1 - 0s - loss: 0.0021 - fn: 21.0000 - fp: 48.0000 - tn: 190.0000 - tp: 111.0000 - precision: 0.6981 - recall: 0.8409 - val_loss: 0.6607 - val_fn: 11.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 17.0000 - val_precision: 0.4474 - val_recall: 0.6071 - 232ms/epoch - 232ms/step
# Epoch 18/30
# 1/1 - 0s - loss: 0.0021 - fn: 21.0000 - fp: 47.0000 - tn: 191.0000 - tp: 111.0000 - precision: 0.7025 - recall: 0.8409 - val_loss: 0.6625 - val_fn: 11.0000 - val_fp: 21.0000 - val_tn: 43.0000 - val_tp: 17.0000 - val_precision: 0.4474 - val_recall: 0.6071 - 169ms/epoch - 169ms/step
# Epoch 19/30
# 1/1 - 0s - loss: 0.0021 - fn: 21.0000 - fp: 47.0000 - tn: 191.0000 - tp: 111.0000 - precision: 0.7025 - recall: 0.8409 - val_loss: 0.6626 - val_fn: 11.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 17.0000 - val_precision: 0.4595 - val_recall: 0.6071 - 223ms/epoch - 223ms/step
# Epoch 20/30
# 1/1 - 0s - loss: 0.0021 - fn: 21.0000 - fp: 46.0000 - tn: 192.0000 - tp: 111.0000 - precision: 0.7070 - recall: 0.8409 - val_loss: 0.6630 - val_fn: 12.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 16.0000 - val_precision: 0.4444 - val_recall: 0.5714 - 85ms/epoch - 85ms/step
# Epoch 21/30
# 1/1 - 0s - loss: 0.0020 - fn: 22.0000 - fp: 43.0000 - tn: 195.0000 - tp: 110.0000 - precision: 0.7190 - recall: 0.8333 - val_loss: 0.6656 - val_fn: 12.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 16.0000 - val_precision: 0.4444 - val_recall: 0.5714 - 113ms/epoch - 113ms/step
# Epoch 22/30
# 1/1 - 0s - loss: 0.0020 - fn: 22.0000 - fp: 43.0000 - tn: 195.0000 - tp: 110.0000 - precision: 0.7190 - recall: 0.8333 - val_loss: 0.6701 - val_fn: 12.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 16.0000 - val_precision: 0.4444 - val_recall: 0.5714 - 87ms/epoch - 87ms/step
# Epoch 23/30
# 1/1 - 0s - loss: 0.0020 - fn: 21.0000 - fp: 43.0000 - tn: 195.0000 - tp: 111.0000 - precision: 0.7208 - recall: 0.8409 - val_loss: 0.6750 - val_fn: 12.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 16.0000 - val_precision: 0.4444 - val_recall: 0.5714 - 95ms/epoch - 95ms/step
# Epoch 24/30
# 1/1 - 0s - loss: 0.0020 - fn: 20.0000 - fp: 42.0000 - tn: 196.0000 - tp: 112.0000 - precision: 0.7273 - recall: 0.8485 - val_loss: 0.6782 - val_fn: 12.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 16.0000 - val_precision: 0.4444 - val_recall: 0.5714 - 134ms/epoch - 134ms/step
# Epoch 25/30
# 1/1 - 0s - loss: 0.0019 - fn: 18.0000 - fp: 39.0000 - tn: 199.0000 - tp: 114.0000 - precision: 0.7451 - recall: 0.8636 - val_loss: 0.6796 - val_fn: 12.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 16.0000 - val_precision: 0.4444 - val_recall: 0.5714 - 88ms/epoch - 88ms/step
# Epoch 26/30
# 1/1 - 0s - loss: 0.0019 - fn: 19.0000 - fp: 38.0000 - tn: 200.0000 - tp: 113.0000 - precision: 0.7483 - recall: 0.8561 - val_loss: 0.6806 - val_fn: 13.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 15.0000 - val_precision: 0.4286 - val_recall: 0.5357 - 112ms/epoch - 112ms/step
# Epoch 27/30
# 1/1 - 0s - loss: 0.0019 - fn: 18.0000 - fp: 37.0000 - tn: 201.0000 - tp: 114.0000 - precision: 0.7550 - recall: 0.8636 - val_loss: 0.6828 - val_fn: 13.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 15.0000 - val_precision: 0.4286 - val_recall: 0.5357 - 94ms/epoch - 94ms/step
# Epoch 28/30
# 1/1 - 0s - loss: 0.0019 - fn: 18.0000 - fp: 37.0000 - tn: 201.0000 - tp: 114.0000 - precision: 0.7550 - recall: 0.8636 - val_loss: 0.6858 - val_fn: 13.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 15.0000 - val_precision: 0.4286 - val_recall: 0.5357 - 139ms/epoch - 139ms/step
# Epoch 29/30
# 1/1 - 0s - loss: 0.0018 - fn: 18.0000 - fp: 37.0000 - tn: 201.0000 - tp: 114.0000 - precision: 0.7550 - recall: 0.8636 - val_loss: 0.6881 - val_fn: 13.0000 - val_fp: 20.0000 - val_tn: 44.0000 - val_tp: 15.0000 - val_precision: 0.4286 - val_recall: 0.5357 - 116ms/epoch - 116ms/step
# Epoch 30/30
# 1/1 - 0s - loss: 0.0018 - fn: 16.0000 - fp: 35.0000 - tn: 203.0000 - tp: 116.0000 - precision: 0.7682 - recall: 0.8788 - val_loss: 0.6889 - val_fn: 13.0000 - val_fp: 19.0000 - val_tn: 45.0000 - val_tp: 15.0000 - val_precision: 0.4412 - val_recall: 0.5357 - 136ms/epoch - 136ms/step

# %%
metrics = [
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]


metrics
# Out:
# [<keras.src.metrics.confusion_metrics.FalseNegatives at 0x7d5ccdead090>,
#  <keras.src.metrics.confusion_metrics.FalsePositives at 0x7d5ccde3a2f0>,
#  <keras.src.metrics.confusion_metrics.TrueNegatives at 0x7d5ccd5cb430>,
#  <keras.src.metrics.confusion_metrics.TruePositives at 0x7d5ccd5cabc0>,
#  <keras.src.metrics.confusion_metrics.Precision at 0x7d5ccd5cbfa0>,
#  <keras.src.metrics.confusion_metrics.Recall at 0x7d5ccdeaf1f0>]

# %%
tn=203.0000
fp=35.0000
fn=16.0000
tp=116.0000
accuracy = (tp + tn) / (tp + tn + fp + fn)

print(accuracy)
# Out:
# 0.8621621621621621

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

# Crear el directorio ./data si no existe
os.makedirs('./data', exist_ok=True)

# Descargar el archivo con gdown
# !pip install gdown
# !gdown https://drive.google.com/uc?id=11jIiAfoZNLA9pvGp6qEtaR2E6EuxYJip -O ./data/SAheart.csv

# Cargar el dataset SAheart
PATH = Path("data", "SAheart.csv")
df = pd.read_csv(PATH)

# Reemplazar valores categóricos con numéricos
df["famhist"] = df["famhist"].replace({"Absent": 0, "Present": 1})
df["chd"] = df["chd"].replace({"No": 0, "Yes": 1})

# Separar features y targets
features = df.drop(columns=["chd"]).values.astype(np.float32)
targets = df["chd"].values.astype(np.uint8)

# Dividir en conjunto de entrenamiento y validación
train_features, val_features, train_targets, val_targets = train_test_split(
    features, targets, test_size=0.2, random_state=42, stratify=targets
)

# Estandarización de datos
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)
val_features = scaler.transform(val_features)

# Análisis del desbalance de clases
class_counts = np.bincount(train_targets)
total_count = len(train_targets)
weight_for_0 = (1 / class_counts[0]) * (total_count / 2.0)
weight_for_1 = (1 / class_counts[1]) * (total_count / 2.0)
class_weight = {0: weight_for_0, 1: weight_for_1}

# Definición del modelo en Keras
model = keras.Sequential([
    keras.layers.Input(shape=train_features.shape[1]),
    keras.layers.Dense(256, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])

# Compilación del modelo
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    loss="binary_crossentropy",
    metrics=[
        keras.metrics.BinaryAccuracy(),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(name='auc')
    ]
)

# Entrenamiento del modelo
history = model.fit(
    train_features, train_targets,
    epochs=30,
    batch_size=2048,
    validation_data=(val_features, val_targets),
    class_weight=class_weight,
    verbose=2
)

# Evaluación del modelo en el conjunto de validación
val_results = model.evaluate(val_features, val_targets)
print("Validation results:")
for name, value in zip(model.metrics_names, val_results):
    print(f"{name}: {value}")

# Guardar el modelo entrenado
model.save("saheart_model.h5")
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.15.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=11jIiAfoZNLA9pvGp6qEtaR2E6EuxYJip
# To: /content/data/SAheart.csv
# 100% 22.2k/22.2k [00:00<00:00, 28.1MB/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-1d473782db40> in <cell line: 27>()
#      25 # Separar features y targets
#      26 features = df.drop(columns=["chd"]).values.astype(np.float32)
# ---> 27 targets = df["chd"].values.astype(np.uint8)
#      28
#      29 # Dividir en conjunto de entrenamiento y validación
#
# ValueError: invalid literal for int() with base 10: 'Si'
